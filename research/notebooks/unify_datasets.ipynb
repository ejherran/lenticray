# %%
MOUNT_POINT = '/content/gdrive'
ROOT_PATH = MOUNT_POINT + "/My Drive/tfm"
DATA_PATH = ROOT_PATH + "/gemsat"
OUT_PATH = ROOT_PATH + "/data"

import os
from google.colab import drive

drive.mount(MOUNT_POINT)
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
STATIONS_SHEET = 'Station_Metadata'
PARAMETERS_SHEET = 'Parameter_Metadata'
METHODS_SHEET = 'Methods_Metadata'
SAMPLE_COLUMS = [
    'GEMS Station Number',
    'Sample Date',
    'Sample Time',
    'Depth',
    'Parameter Code',
    'Analysis Method Code',
    'Value Flags',
    'Value',
    'Unit',
    'Data Quality'
]
FIX_TYPES = {'Parameter Code': str, 'Analysis Method Code': str}

# %%
import pandas as pd

# %%
p1_stations = pd.read_excel(f"{DATA_PATH}/p1/metadata.xlsx", sheet_name=STATIONS_SHEET)
p1_parameters = pd.read_excel(f"{DATA_PATH}/p1/metadata.xlsx", sheet_name=PARAMETERS_SHEET)
p1_methods = pd.read_excel(f"{DATA_PATH}/p1/metadata.xlsx", sheet_name=METHODS_SHEET)

# %%
p2_stations = pd.read_excel(f"{DATA_PATH}/p2/metadata.xlsx", sheet_name=STATIONS_SHEET)
p2_parameters = pd.read_excel(f"{DATA_PATH}/p2/metadata.xlsx", sheet_name=PARAMETERS_SHEET)
p2_methods = pd.read_excel(f"{DATA_PATH}/p2/metadata.xlsx", sheet_name=METHODS_SHEET)

# %%
p3_stations = pd.read_excel(f"{DATA_PATH}/p3/metadata.xlsx", sheet_name=STATIONS_SHEET)
p3_parameters = pd.read_excel(f"{DATA_PATH}/p3/metadata.xlsx", sheet_name=PARAMETERS_SHEET)
p3_methods = pd.read_excel(f"{DATA_PATH}/p3/metadata.xlsx", sheet_name=METHODS_SHEET)

# %%
p1_samples = pd.read_csv(
    f"{DATA_PATH}/p1/samples.csv",
    sep=';',
    names=SAMPLE_COLUMS,
    dtype=FIX_TYPES,
)

# %%
p1_samples.head()
# Out:
#   GEMS Station Number Sample Date Sample Time  Depth Parameter Code  \
# 0            ARG00010  1993-11-26       10:00    5.0             EC
# 1            ARG00010  1993-11-26       10:00    5.0           NOxN
# 2            ARG00010  1993-11-26       10:00    5.0         Mg-Dis
# 3            ARG00010  1993-11-26       10:10   40.0         Ca-Dis
# 4            ARG00010  1993-11-26       10:10   40.0           NOxN
#
#   Analysis Method Code Value Flags  Value   Unit Data Quality
# 0            EC-CND-Pt         NaN  30.00  µS/cm         Fair
# 1           COL-AZO-Cd         NaN   0.01   mg/l         Fair
# 2       T-COL-EDTA-EBT         NaN   1.00   mg/l         Fair
# 3       T-COL-EDTA-HNB         NaN   3.00   mg/l         Fair
# 4           COL-AZO-Cd         NaN   0.01   mg/l         Fair

# %%
quality = p1_samples['Data Quality'].value_counts()
display(quality)
# Out:
# Data Quality
# Fair       447446
# Unknown     28038
# Suspect     11768
# Poor         2242
# Name: count, dtype: int64

# %%
p2_samples = pd.read_csv(
    f"{DATA_PATH}/p2/samples.csv",
    sep=';',
    names=SAMPLE_COLUMS,
    dtype=FIX_TYPES,
)

# %%
p2_samples.head()
# Out:
#   GEMS Station Number Sample Date Sample Time  Depth Parameter Code  \
# 0            IRL00050  2015-12-22       00:00    0.0             TP
# 1            IRL00050  2015-12-22       00:00    0.0           HCO3
# 2            IRL00050  2015-02-17       00:00    0.0         O2-Dis
# 3            IRL00050  2015-04-21       00:00    0.0          Chl-a
# 4            IRL00050  2015-04-21       00:00    0.0         O2-Dis
#
#   Analysis Method Code Value Flags    Value  Unit Data Quality
# 0                    0         NaN    0.037  mg/l         Fair
# 1                    0         NaN  163.000  mg/l         Fair
# 2                    0         NaN   12.300  mg/l         Fair
# 3                    0         NaN    0.012  mg/l         Fair
# 4                    0         NaN   11.600  mg/l         Fair

# %%
quality = p2_samples['Data Quality'].value_counts()
display(quality)
# Out:
# Data Quality
# Fair       513896
# Unknown    174697
# Suspect     31488
# Poor          603
# Good            1
# Name: count, dtype: int64

# %%
p3_samples = pd.read_csv(
    f"{DATA_PATH}/p3/samples.csv",
    sep=';',
    names=SAMPLE_COLUMS,
    dtype=FIX_TYPES,
)

# %%
p3_samples.head()
# Out:
#   GEMS Station Number Sample Date Sample Time  Depth Parameter Code  \
# 0            MEX05423  2012-11-15       12:00    1.0           TEMP
# 1            MEX05423  2012-11-15       12:00    0.3             EC
# 2            MEX05423  2012-11-15       12:00    0.5         Pb-Tot
# 3            MEX05423  2012-11-15       12:00    0.5         Ni-Tot
# 4            MEX05423  2012-11-15       12:00    0.5         Cr-Tot
#
#   Analysis Method Code Value Flags     Value   Unit Data Quality
# 0                    0         NaN    27.000     °C      Suspect
# 1                    0         NaN  7437.000  µS/cm      Unknown
# 2                    0           <     0.005   mg/l      Unknown
# 3                    0         NaN     0.077   mg/l      Unknown
# 4                    0           <     0.005   mg/l      Unknown

# %%
p3_samples['Data Quality'] = p3_samples['Data Quality'].replace('1Good', 'Good')

# %%
quality = p3_samples['Data Quality'].value_counts()
display(quality)
# Out:
# Data Quality
# Fair       1536898
# Unknown     150749
# Suspect       8930
# Poor          2878
# Good             6
# Name: count, dtype: int64

# %%
p1_samples_filter = p1_samples[p1_samples['Data Quality'].isin(['Fair', 'Good'])]
p2_samples_filter = p2_samples[p2_samples['Data Quality'].isin(['Fair', 'Good'])]
p3_samples_filter = p3_samples[p3_samples['Data Quality'].isin(['Fair', 'Good'])]

# %%
full_samples = pd.concat([p1_samples_filter, p2_samples_filter, p3_samples_filter])
full_samples.reset_index(drop=True, inplace=True)

# %%
full_samples.head()
# Out:
#   GEMS Station Number Sample Date Sample Time  Depth Parameter Code  \
# 0            ARG00010  1993-11-26       10:00    5.0             EC
# 1            ARG00010  1993-11-26       10:00    5.0           NOxN
# 2            ARG00010  1993-11-26       10:00    5.0         Mg-Dis
# 3            ARG00010  1993-11-26       10:10   40.0         Ca-Dis
# 4            ARG00010  1993-11-26       10:10   40.0           NOxN
#
#   Analysis Method Code Value Flags  Value   Unit Data Quality
# 0            EC-CND-Pt         NaN  30.00  µS/cm         Fair
# 1           COL-AZO-Cd         NaN   0.01   mg/l         Fair
# 2       T-COL-EDTA-EBT         NaN   1.00   mg/l         Fair
# 3       T-COL-EDTA-HNB         NaN   3.00   mg/l         Fair
# 4           COL-AZO-Cd         NaN   0.01   mg/l         Fair

# %%
quality = full_samples['Data Quality'].value_counts()
display(quality)
# Out:
# Data Quality
# Fair    2498240
# Good          7
# Name: count, dtype: int64

# %%
full_stations = pd.concat([p1_stations, p2_stations, p3_stations])
full_stations = full_stations[full_stations['GEMS Station Number'].isin(full_samples['GEMS Station Number'])]
full_stations.loc[:, 'Historical GEMS Number'] = full_stations['Historical GEMS Number'].astype(str)
full_stations.reset_index(drop=True, inplace=True)

# %%
full_stations.shape
# Out:
# (1528, 27)

# %%
full_parameters = pd.concat([p1_parameters, p2_parameters, p3_parameters])
full_parameters.drop_duplicates(inplace=True)
full_parameters.reset_index(drop=True, inplace=True)

# %%
full_parameters.head()
# Out:
#   Parameter Code Parameter Name   Parameter Long Name  \
# 0         Ag-Dis         Silver    Silver - Dissolved
# 1         Ag-Ext         Silver  Silver - Extractable
# 2         Ag-Tot         Silver        Silver - Total
# 3         Al-Dis       Aluminum  Aluminum - Dissolved
# 4         ALDRIN         Aldrin                Aldrin
#
#                Parameter Group  EC Number CAS Number  ChEBI Number  \
# 0    /Chemical/Inorganic/Metal  231-131-3  7440-22-4        9141.0
# 1    /Chemical/Inorganic/Metal  231-131-3  7440-22-4        9141.0
# 2    /Chemical/Inorganic/Metal  231-131-3  7440-22-4        9141.0
# 3    /Chemical/Inorganic/Metal  231-072-3  7429-90-5       28984.0
# 4  /Chemical/Organic/Pesticide  206-215-8   309-00-2        2564.0
#
#                                Parameter Description
# 0  Silver fraction in an unacidified sample that ...
# 1  Silver fraction in solution after treatment of...
# 2  Silver fraction in an unfiltered sample after ...
# 3  Aluminum fraction in an unacidified sample tha...
# 4  C12H8Cl6, (1R,4S,4aS,5S,8R,8aR)-1,2,3,4,10,10-...

# %%
full_methods = pd.concat([p1_methods, p2_methods, p3_methods])
full_methods.drop_duplicates(inplace=True)
full_methods.reset_index(drop=True, inplace=True)

# %%
full_methods.head()
# Out:
#   Parameter Code Analysis Method Code  Unit   Parameter Long Name  \
# 0         Ag-Dis           FAAS-AAc-D  mg/l    Silver - Dissolved
# 1         Ag-Ext           FAAS-AAc-E  mg/l  Silver - Extractable
# 2         Ag-Tot          ICP-AES-Dgs  mg/l        Silver - Total
# 3         Ag-Tot          ICP-AES-Xtr  mg/l        Silver - Total
# 4         Ag-Tot           ICP-MS-CVD  mg/l        Silver - Total
#
#                                          Method Name   Method Type  \
# 0  Direct Air-Acetylene Flame Atomic Absorption S...  Spectroscopy
# 1  Extraction/Air-Acetylene Flame Atomic Absorpti...  Spectroscopy
# 2  Inductively Coupled Plasma (ICP) Method (Total...  Spectroscopy
# 3  Inductively Coupled Plasma (ICP) Method (Extra...  Spectroscopy
# 4  Inductively-Coupled Plasma Mass Spectrometry w...  Spectroscopy
#
#        Method Number Method Source  \
# 0          SM 3111 B     APHA 2012
# 1          SM 3111 C     APHA 2012
# 2          SM 3120 B     APHA 2012
# 3  SM 3120 B, 3030 C     APHA 2012
# 4          SM 3125 B     APHA 2012
#
#                                   Method Description
# 0  A sample is preserved in the field with EDTA/n...
# 1  The whole water sample, preserved with EDTA, i...
# 2  Preconcentration by evaporation to near drynes...
# 3  Digestion with HNO3/HCl. Preconcentration by e...
# 4  Water samples are preserved at 2% nitric acid ...

# %%
full_samples.to_parquet(f"{OUT_PATH}/samples.parquet")
full_stations.to_parquet(f"{OUT_PATH}/stations.parquet")
full_parameters.to_parquet(f"{OUT_PATH}/parameters.parquet")
full_methods.to_parquet(f"{OUT_PATH}/methods.parquet")

# %%
full_stations.to_excel(f"{OUT_PATH}/stations.xlsx")
full_parameters.to_excel(f"{OUT_PATH}/parameters.xlsx")
full_methods.to_excel(f"{OUT_PATH}/methods.xlsx")
